# %% [markdown]
# ## Install and List Library

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.1.4)

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (6.0.2)

# %%
import requests
from bs4 import BeautifulSoup
import lxml
from urllib.parse import urljoin

# %% [markdown]
# ### Get book_detail (Detail buku dari halaman buku tertentu)

# %%
def book_detail(url_detail):
  page = requests.get(url_detail).text

  soup = BeautifulSoup(page, 'lxml')

  # Get book details
  book_detail_page = soup.find('article', class_='product_page')

  # Get availability
  head_col = book_detail_page.find('div', class_ = 'col-sm-6 product_main')
  instock = head_col.find('p', class_='instock availability').get_text(strip=True).split(' ')[2]
  availability = instock.replace('(', '')

  # Get UPC (United Product Code)
  product_info = book_detail_page.find('table', class_ = 'table table-striped')
  upc = product_info.find('tr').find('td').get_text()

  detail = {
      'availability' : availability,
      'upc' : upc
  }

  return detail

# %% [markdown]
# ### Get Book Overview

# %%
def book_overview():
  url_html = f'https://books.toscrape.com/'
  page = requests.get(url_html).text

  soup = BeautifulSoup(page, 'lxml')

  # Get book overview
  book_cards = soup.find_all('article', class_='product_pod')

  data = []
  for book_card in book_cards:
    # Scrape Title of the book
    h3_tag = book_card.find('h3')
    a_tag = h3_tag.find('a')
    full_title = a_tag['title']
    book_link = a_tag['href']

    full_url = url_html + book_link
    detail_product = book_detail(full_url)

    # Scrape Price of the book
    price_tag = book_card.find('p', class_ = 'price_color').text
    price = price_tag.split('£')[-1]
    # Scrape Availability
    stock_status = book_card.find('p', class_='instock availability').get_text(strip=True)

    data.append({
        'title' : full_title,
        'upc' : detail_product['upc'],
        'price' : float(price),
        'stock_status' : stock_status,
        'availability' : detail_product['availability']
    })

  return data

# %%
import pandas as pd

buku = book_overview()
dataBuku = pd.DataFrame(buku)
dataBuku
# Out:
#                                                 title               upc  \
# 0                                A Light in the Attic  a897fe39b1053632
# 1                                  Tipping the Velvet  90fa61229261140a
# 2                                          Soumission  6957f44c3847a760
# 3                                       Sharp Objects  e00eb4fd7b871a48
# 4               Sapiens: A Brief History of Humankind  4165285e1663650f
# 5                                     The Requiem Red  f77dbf2323deb740
# 6   The Dirty Little Secrets of Getting Your Dream...  2597b5a345f45e1b
# 7   The Coming Woman: A Novel Based on the Life of...  e72a5dfc7e9267b2
# 8   The Boys in the Boat: Nine Americans and Their...  e10e1e165dc8be4a
# 9                                     The Black Maria  1dfe412b8ac00530
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  0312262ecafa5a40
# 11                              Shakespeare's Sonnets  30a7f60cd76ca58c
# 12                                        Set Me Free  ce6396b0f23f6ecc
# 13  Scott Pilgrim's Precious Little Life (Scott Pi...  3b1c02bac2a429e6
# 14                          Rip it Up and Start Again  a34ba96d4081e6a4
# 15  Our Band Could Be Your Life: Scenes from the A...  deda3e61b9514b83
# 16                                               Olio  feb7cc7701ecf901
# 17  Mesaerion: The Best Science Fiction Stories 18...  e30f54cea9b38190
# 18                       Libertarianism for Beginners  a18a4f574854aced
# 19                            It's Only the Himalayas  a22124811bfa8350
#
#     price stock_status availability
# 0   51.77     In stock           22
# 1   53.74     In stock           20
# 2   50.10     In stock           20
# 3   47.82     In stock           20
# 4   54.23     In stock           20
# 5   22.65     In stock           19
# 6   33.34     In stock           19
# 7   17.93     In stock           19
# 8   22.60     In stock           19
# 9   52.15     In stock           19
# 10  13.99     In stock           19
# 11  20.66     In stock           19
# 12  17.46     In stock           19
# 13  52.29     In stock           19
# 14  35.02     In stock           19
# 15  57.25     In stock           19
# 16  23.88     In stock           19
# 17  37.59     In stock           19
# 18  51.33     In stock           19
# 19  45.17     In stock           19

# %% [markdown]
# ### Get All Data From Web with Pagination

# %%
def scrape_with_next_button():
    current_url = "https://books.toscrape.com/index.html"
    base_url = "https://books.toscrape.com/"
    data = []

    while current_url:
        print(f"Sedang memproses link: {current_url}")
        res = requests.get(current_url).text
        soup = BeautifulSoup(res, 'lxml')

        # Get book overview
        book_cards = soup.find_all('article', class_='product_pod')

        # get all data
        for book_card in book_cards:
          # Scrape Title of the book
          h3_tag = book_card.find('h3')
          a_tag = h3_tag.find('a')
          full_title = a_tag['title']
          book_link = a_tag['href']

          full_url = urljoin(current_url, book_link)
          detail_product = book_detail(full_url)

          # Scrape Price of the book
          price_tag = book_card.find('p', class_ = 'price_color').text
          price = price_tag.split('£')[-1]
          # Scrape Availability
          stock_status = book_card.find('p', class_='instock availability').get_text(strip=True)

          data.append({
              'title' : full_title,
              'upc' : detail_product['upc'],
              'price' : float(price),
              'stock_status' : stock_status,
              'availability' : detail_product['availability']
          })

        # --- Bagian Mencari Halaman Berikutnya ---
        next_tag = soup.find('li', class_='next')

        if next_tag:
            # Ambil href dari tombol next
            next_href = next_tag.find('a')['href']
            # Logika join URL yang lebih aman
            if "catalogue/" in next_href:
                current_url = urljoin(base_url, next_href)
            else:
                current_url = base_url + "catalogue/" + next_href

        else:
            # Jika tidak ada tombol next, hentikan loop
            current_url = None
            print("Semua halaman selesai diambil.")

    return data

# %%
import pandas as pd

all_books = scrape_with_next_button()
# Out:
# Sedang memproses link: https://books.toscrape.com/index.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-2.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-3.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-4.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-5.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-6.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-7.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-8.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-9.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-10.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-11.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-12.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-13.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-14.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-15.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-16.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-17.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-18.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-19.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-20.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-21.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-22.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-23.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-24.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-25.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-26.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-27.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-28.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-29.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-30.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-31.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-32.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-33.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-34.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-35.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-36.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-37.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-38.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-39.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-40.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-41.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-42.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-43.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-44.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-45.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-46.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-47.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-48.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-49.html
# Sedang memproses link: https://books.toscrape.com/catalogue/page-50.html
# Semua halaman selesai diambil.

# %%
df = pd.DataFrame(all_books)
df
# Out:
#                                                  title               upc  \
# 0                                 A Light in the Attic  a897fe39b1053632
# 1                                   Tipping the Velvet  90fa61229261140a
# 2                                           Soumission  6957f44c3847a760
# 3                                        Sharp Objects  e00eb4fd7b871a48
# 4                Sapiens: A Brief History of Humankind  4165285e1663650f
# ..                                                 ...               ...
# 995  Alice in Wonderland (Alice's Adventures in Won...  cd2a2a70dd5d176d
# 996   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)  bfd5e1701c862ac3
# 997  A Spy's Devotion (The Regency Spies of London #1)  19fec36a1dfb4c16
# 998                1st to Die (Women's Murder Club #1)  f684a82adc49f011
# 999                 1,000 Places to See Before You Die  228ba5e7577e1d49
#
#      price stock_status availability
# 0    51.77     In stock           22
# 1    53.74     In stock           20
# 2    50.10     In stock           20
# 3    47.82     In stock           20
# 4    54.23     In stock           20
# ..     ...          ...          ...
# 995  55.53     In stock            1
# 996  57.06     In stock            1
# 997  16.97     In stock            1
# 998  53.98     In stock            1
# 999  26.08     In stock            1
#
# [1000 rows x 5 columns]

# %%
df.to_csv('web_scrape_books.csv', index=False)
